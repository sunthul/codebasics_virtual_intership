# %% [markdown]
# <h2 align='center' style='color:blue'>Campaign Performance Analysis - Nova Mart</h2>

# %% [markdown]
# # import library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Import Datas

# %% [markdown]
# ## dim_campaigns

# %%
df_campaigns_1 = pd.read_csv('dim_campaigns.csv')
df_campaigns_1.head(3)
# Out:
#    campaign_id campaign_name  start_date    end_date
# 0  CAMP_DIW_01        Diwali  12-11-2023  18-11-2023
# 1  CAMP_SAN_01     Sankranti  10-01-2024  16-01-2024

# %%
df_campaigns_1.shape
# Out:
# (2, 4)

# %% [markdown]
# ## dim_products

# %%
df_products_1 = pd.read_csv('dim_products.csv')
df_products_1.head()
# Out:
#   product_code                     product_name           category
# 0          P01           Atliq_Masoor_Dal (1KG)  Grocery & Staples
# 1          P02     Atliq_Sonamasuri_Rice (10KG)  Grocery & Staples
# 2          P03          Atliq_Suflower_Oil (1L)  Grocery & Staples
# 3          P04     Atliq_Farm_Chakki_Atta (1KG)  Grocery & Staples
# 4          P05  Atliq_Scrub_Sponge_For_Dishwash          Home Care

# %%
df_products_1.shape
# Out:
# (15, 3)

# %% [markdown]
# ## dim_stores

# %%
df_dim_stores_1 = pd.read_csv('dim_stores.csv')
df_dim_stores_1.head()
# Out:
#   store_id           city
# 0  STTRV-0     Trivandrum
# 1  STMDU-3        Madurai
# 2  STHYD-6      Hyderabad
# 3  STVSK-1  Visakhapatnam
# 4  STCBE-3     Coimbatore

# %%
df_dim_stores_1.shape
# Out:
# (50, 2)

# %% [markdown]
# ### fact_events

# %%
df_fact_events_1 = pd.read_csv('fact_events.csv')
df_fact_events_1.head()
# Out:
#   event_id store_id  campaign_id product_code  base_price(before_promo)  \
# 0   8481be  STCHE-1  CAMP_DIW_01          P04                       290
# 1   20618e  STCHE-3  CAMP_SAN_01          P04                       370
# 2   f30579  STBLR-9  CAMP_DIW_01          P02                       860
# 3   4f570c  STBLR-7  CAMP_DIW_01          P05                        55
# 4   6d153f  STHYD-5  CAMP_SAN_01          P15                      3000
#
#    quantity_sold(before_promo)    promo_type  base_price(after_promo)  \
# 0                        327.0       25% OFF                      217
# 1                        379.0         BOGOF                      185
# 2                        337.0       33% OFF                      576
# 3                        122.0       25% OFF                       41
# 4                        122.0  500 Cashback                     2500
#
#    quantity_sold(after_promo)
# 0                         287
# 1                        1622
# 2                         488
# 3                         107
# 4                         272

# %%
df_fact_events_1.shape
# Out:
# (1510, 9)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Removes Duplicates

# %%
# Count duplicates based on store_id, campaign_id, and product_code
num_duplicates = df_fact_events_1.duplicated(subset=['store_id', 'campaign_id', 'product_code']).sum()

# Remove the duplicate rows
df_fact_events_2 = df_fact_events_1.drop_duplicates(subset=['store_id', 'campaign_id', 'product_code']).copy()

print(f"Removed {num_duplicates} duplicate rows.")
# Out:
# Removed 10 duplicate rows.

# %% [markdown]
# ## Removes Null

# %%
df_fact_events_2.isnull().sum()
# Out:
# event_id                        0
# store_id                        0
# campaign_id                     0
# product_code                    0
# base_price(before_promo)        0
# quantity_sold(before_promo)    20
# promo_type                      0
# base_price(after_promo)         0
# quantity_sold(after_promo)      0
# dtype: int64

# %%
df_fact_events_2['quantity_sold(before_promo)'].median()
# Out:
# np.float64(78.0)

# %%
df_fact_null = df_fact_events_2.loc[df_fact_events_2['quantity_sold(before_promo)'].isna()==True]
df_fact_null.head()
# Out:
#     event_id store_id  campaign_id product_code  base_price(before_promo)  \
# 63    70c312  STHYD-4  CAMP_SAN_01          P13                       350
# 119   d31787  STMYS-2  CAMP_SAN_01          P10                        50
# 141   141d98  STCHE-4  CAMP_SAN_01          P03                       200
# 163   873333  STMLR-0  CAMP_DIW_01          P15                      3000
# 341   2ef46d  STMDU-0  CAMP_DIW_01          P02                       860
#
#      quantity_sold(before_promo)    promo_type  base_price(after_promo)  \
# 63                           NaN         BOGOF                      175
# 119                          NaN       25% OFF                       37
# 141                          NaN         BOGOF                      100
# 163                          NaN  500 Cashback                     2500
# 341                          NaN       33% OFF                      576
#
#      quantity_sold(after_promo)
# 63                          534
# 119                          20
# 141                        1695
# 163                         509
# 341                         430

# %%
df_fact_null.index
# Out:
# Index([  63,  119,  141,  163,  341,  391,  558,  714,  745,  758,  924,  967,
#        1035, 1072, 1163, 1164, 1196, 1247, 1419, 1507],
#       dtype='int64')

# %%
df_fact_events_2.loc[df_fact_events_2.product_code=='P13'].sample(5)
# Out:
#      event_id store_id  campaign_id product_code  base_price(before_promo)  \
# 879    f7aec5  STCHE-5  CAMP_SAN_01          P13                       350
# 1070   b8269b  STBLR-1  CAMP_DIW_01          P13                       350
# 199    60ba75  STVJD-0  CAMP_SAN_01          P13                       350
# 1236   407f1c  STBLR-2  CAMP_SAN_01          P13                       350
# 685    f940cf  STHYD-6  CAMP_DIW_01          P13                       350
#
#       quantity_sold(before_promo) promo_type  base_price(after_promo)  \
# 879                          87.0      BOGOF                      175
# 1070                         77.0      BOGOF                      175
# 199                          60.0      BOGOF                      175
# 1236                        117.0      BOGOF                      175
# 685                          77.0      BOGOF                      175
#
#       quantity_sold(after_promo)
# 879                          341
# 1070                         232
# 199                          234
# 1236                         469
# 685                          260

# %%
df_prod_prom = df_fact_events_2.groupby(['product_code','promo_type'])['quantity_sold(before_promo)'].agg('median').round()
df_prod_prom.head()
# Out:
# product_code  promo_type
# P01           33% OFF       272.0
# P02           33% OFF       366.0
# P03           25% OFF       314.0
#               BOGOF         331.0
# P04           25% OFF       291.0
# Name: quantity_sold(before_promo), dtype: float64

# %%
def qty_sold_null(row):
    if pd.isnull(row['quantity_sold(before_promo)']):
        return df_prod_prom.loc[row['product_code'], row['promo_type']]
    else:
        return row['quantity_sold(before_promo)']

# %%
df_fact_events_2['quantity_sold(before_promo)'] = df_fact_events_2.apply(qty_sold_null, axis=1)

# %%
df_fact_events_2.head()
# Out:
#   event_id store_id  campaign_id product_code  base_price(before_promo)  \
# 0   8481be  STCHE-1  CAMP_DIW_01          P04                       290
# 1   20618e  STCHE-3  CAMP_SAN_01          P04                       370
# 2   f30579  STBLR-9  CAMP_DIW_01          P02                       860
# 3   4f570c  STBLR-7  CAMP_DIW_01          P05                        55
# 4   6d153f  STHYD-5  CAMP_SAN_01          P15                      3000
#
#    quantity_sold(before_promo)    promo_type  base_price(after_promo)  \
# 0                        327.0       25% OFF                      217
# 1                        379.0         BOGOF                      185
# 2                        337.0       33% OFF                      576
# 3                        122.0       25% OFF                       41
# 4                        122.0  500 Cashback                     2500
#
#    quantity_sold(after_promo)
# 0                         287
# 1                        1622
# 2                         488
# 3                         107
# 4                         272

# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## How many cities have more than 5 stores?

# %%
result = df_dim_stores_1['city'].value_counts().loc[lambda x: x > 5]
result
# Out:
# city
# Bengaluru    10
# Chennai       8
# Hyderabad     7
# Name: count, dtype: int64

# %% [markdown]
# ## Total Quantity Sold BOGOF during Diwali

# %% [markdown]
# ### Merge all dataset

# %% [markdown]
# #### event x store

# %%
df_merge_1 = pd.merge(df_fact_events_2,df_dim_stores_1,on='store_id')
df_merge_1.head(2)
# Out:
#   event_id store_id  campaign_id product_code  base_price(before_promo)  \
# 0   8481be  STCHE-1  CAMP_DIW_01          P04                       290
# 1   20618e  STCHE-3  CAMP_SAN_01          P04                       370
#
#    quantity_sold(before_promo) promo_type  base_price(after_promo)  \
# 0                        327.0    25% OFF                      217
# 1                        379.0      BOGOF                      185
#
#    quantity_sold(after_promo)     city
# 0                         287  Chennai
# 1                        1622  Chennai

# %% [markdown]
# #### event x product

# %%
df_merge_1 = pd.merge(df_merge_1,df_products_1,on='product_code')
df_merge_1.head(2)
# Out:
#   event_id store_id  campaign_id product_code  base_price(before_promo)  \
# 0   8481be  STCHE-1  CAMP_DIW_01          P04                       290
# 1   20618e  STCHE-3  CAMP_SAN_01          P04                       370
#
#    quantity_sold(before_promo) promo_type  base_price(after_promo)  \
# 0                        327.0    25% OFF                      217
# 1                        379.0      BOGOF                      185
#
#    quantity_sold(after_promo)     city                  product_name  \
# 0                         287  Chennai  Atliq_Farm_Chakki_Atta (1KG)
# 1                        1622  Chennai  Atliq_Farm_Chakki_Atta (1KG)
#
#             category
# 0  Grocery & Staples
# 1  Grocery & Staples

# %% [markdown]
# #### event x campaigns

# %%
df_merge_1 = pd.merge(df_merge_1,df_campaigns_1,on='campaign_id').drop('campaign_id',axis=1)
df_merge_1.head(2)
# Out:
#   event_id store_id product_code  base_price(before_promo)  \
# 0   8481be  STCHE-1          P04                       290
# 1   20618e  STCHE-3          P04                       370
#
#    quantity_sold(before_promo) promo_type  base_price(after_promo)  \
# 0                        327.0    25% OFF                      217
# 1                        379.0      BOGOF                      185
#
#    quantity_sold(after_promo)     city                  product_name  \
# 0                         287  Chennai  Atliq_Farm_Chakki_Atta (1KG)
# 1                        1622  Chennai  Atliq_Farm_Chakki_Atta (1KG)
#
#             category campaign_name  start_date    end_date
# 0  Grocery & Staples        Diwali  12-11-2023  18-11-2023
# 1  Grocery & Staples     Sankranti  10-01-2024  16-01-2024

# %% [markdown]
# #### reset_index

# %%
df_merge_1 = df_merge_1.reset_index(drop=True).set_index('event_id')
df_merge_1.head(2)
# Out:
#          store_id product_code  base_price(before_promo)  \
# event_id
# 8481be    STCHE-1          P04                       290
# 20618e    STCHE-3          P04                       370
#
#           quantity_sold(before_promo) promo_type  base_price(after_promo)  \
# event_id
# 8481be                          327.0    25% OFF                      217
# 20618e                          379.0      BOGOF                      185
#
#           quantity_sold(after_promo)     city                  product_name  \
# event_id
# 8481be                           287  Chennai  Atliq_Farm_Chakki_Atta (1KG)
# 20618e                          1622  Chennai  Atliq_Farm_Chakki_Atta (1KG)
#
#                    category campaign_name  start_date    end_date
# event_id
# 8481be    Grocery & Staples        Diwali  12-11-2023  18-11-2023
# 20618e    Grocery & Staples     Sankranti  10-01-2024  16-01-2024

# %% [markdown]
# #### cast to datetime

# %%
df_merge_1 = df_merge_1.astype({
    'start_date': 'datetime64[ns]',
    'end_date': 'datetime64[ns]'
})
df_merge_1.head()
# Out:
#          store_id product_code  base_price(before_promo)  \
# event_id
# 8481be    STCHE-1          P04                       290
# 20618e    STCHE-3          P04                       370
# f30579    STBLR-9          P02                       860
# 4f570c    STBLR-7          P05                        55
# 6d153f    STHYD-5          P15                      3000
#
#           quantity_sold(before_promo)    promo_type  base_price(after_promo)  \
# event_id
# 8481be                          327.0       25% OFF                      217
# 20618e                          379.0         BOGOF                      185
# f30579                          337.0       33% OFF                      576
# 4f570c                          122.0       25% OFF                       41
# 6d153f                          122.0  500 Cashback                     2500
#
#           quantity_sold(after_promo)       city  \
# event_id
# 8481be                           287    Chennai
# 20618e                          1622    Chennai
# f30579                           488  Bengaluru
# 4f570c                           107  Bengaluru
# 6d153f                           272  Hyderabad
#
#                                   product_name           category  \
# event_id
# 8481be            Atliq_Farm_Chakki_Atta (1KG)  Grocery & Staples
# 20618e            Atliq_Farm_Chakki_Atta (1KG)  Grocery & Staples
# f30579            Atliq_Sonamasuri_Rice (10KG)  Grocery & Staples
# 4f570c         Atliq_Scrub_Sponge_For_Dishwash          Home Care
# 6d153f    Atliq_Home_Essential_8_Product_Combo             Combo1
#
#          campaign_name start_date   end_date
# event_id
# 8481be          Diwali 2023-12-11 2023-11-18
# 20618e       Sankranti 2024-10-01 2024-01-16
# f30579          Diwali 2023-12-11 2023-11-18
# 4f570c          Diwali 2023-12-11 2023-11-18
# 6d153f       Sankranti 2024-10-01 2024-01-16

# %% [markdown]
# ### Total Qty Sold

# %%
tqs = df_merge_1.loc[(df_merge_1.promo_type == 'BOGOF') & (df_merge_1.campaign_name == 'Diwali'),'quantity_sold(after_promo)'].sum()
tqs
# Out:
# np.int64(34461)

# %% [markdown]
# ## Best Store Performance

# %%
df_merge_1.loc[df_merge_1.campaign_name=='Diwali'].groupby('store_id')['quantity_sold(after_promo)'].agg('sum')
# Out:
# store_id
# STBLR-0    4759
# STBLR-1    4146
# STBLR-2    4169
# STBLR-3    4373
# STBLR-4    4408
# STBLR-5    4193
# STBLR-6    4857
# STBLR-7    4893
# STBLR-8    4395
# STBLR-9    4186
# STCBE-0    3381
# STCBE-1    2942
# STCBE-2    3093
# STCBE-3    3077
# STCBE-4    2907
# STCHE-0    4100
# STCHE-1    3595
# STCHE-2    4093
# STCHE-3    4605
# STCHE-4    5013
# STCHE-5    4052
# STCHE-6    4445
# STCHE-7    4779
# STHYD-0    4460
# STHYD-1    3778
# STHYD-2    4266
# STHYD-3    4272
# STHYD-4    4227
# STHYD-5    4346
# STHYD-6    4153
# STMDU-0    3545
# STMDU-1    3266
# STMDU-2    2981
# STMDU-3    3071
# STMLR-0    2027
# STMLR-1    2151
# STMLR-2    2138
# STMYS-0    3543
# STMYS-1    4779
# STMYS-2    4130
# STMYS-3    4347
# STTRV-0    2180
# STTRV-1    2072
# STVJD-0    2392
# STVJD-1    2312
# STVSK-0    3005
# STVSK-1    3078
# STVSK-2    2860
# STVSK-3    2656
# STVSK-4    2908
# Name: quantity_sold(after_promo), dtype: int64

# %% [markdown]
# ## Best Campaign

# %% [markdown]
# ### groupby campaign_name and promo_type

# %%
df_best_campaign = df_merge_1.groupby(['campaign_name','promo_type'])[['quantity_sold(before_promo)',
                                                                    'quantity_sold(after_promo)',
                                                                       ]].agg('sum')
df_best_campaign
# Out:
#                             quantity_sold(before_promo)  \
# campaign_name promo_type
# Diwali        25% OFF                           37479.0
#               33% OFF                           29240.0
#               50% OFF                           16873.0
#               500 Cashback                      16513.0
#               BOGOF                             10018.0
# Sankranti     25% OFF                            6501.0
#               33% OFF                           34300.0
#               50% OFF                            4440.0
#               500 Cashback                       5573.0
#               BOGOF                             48045.0
#
#                             quantity_sold(after_promo)
# campaign_name promo_type
# Diwali        25% OFF                            32983
#               33% OFF                            43117
#               50% OFF                            22074
#               500 Cashback                       50769
#               BOGOF                              34461
# Sankranti     25% OFF                             5307
#               33% OFF                            47459
#               50% OFF                             6100
#               500 Cashback                       12411
#               BOGOF                             180792

# %% [markdown]
# ### add diff column

# %%
df_best_campaign['diff'] = df_best_campaign['quantity_sold(after_promo)'] - df_best_campaign['quantity_sold(before_promo)']
df_best_campaign
# Out:
#                             quantity_sold(before_promo)  \
# campaign_name promo_type
# Diwali        25% OFF                           37479.0
#               33% OFF                           29240.0
#               50% OFF                           16873.0
#               500 Cashback                      16513.0
#               BOGOF                             10018.0
# Sankranti     25% OFF                            6501.0
#               33% OFF                           34300.0
#               50% OFF                            4440.0
#               500 Cashback                       5573.0
#               BOGOF                             48045.0
#
#                             quantity_sold(after_promo)      diff
# campaign_name promo_type
# Diwali        25% OFF                            32983   -4496.0
#               33% OFF                            43117   13877.0
#               50% OFF                            22074    5201.0
#               500 Cashback                       50769   34256.0
#               BOGOF                              34461   24443.0
# Sankranti     25% OFF                             5307   -1194.0
#               33% OFF                            47459   13159.0
#               50% OFF                             6100    1660.0
#               500 Cashback                       12411    6838.0
#               BOGOF                             180792  132747.0

# %% [markdown]
# ### find the best campaign and what event

# %%
# Get the index (a tuple) of the row with the maximum diff value
best_idx = df_best_campaign['diff'].idxmax()

# Unpack the tuple (campaign_name, promo_type)
best_campaign, best_promo = best_idx

print("Best campaign:", best_campaign)
print("Best promo type:", best_promo)
# Out:
# Best campaign: Sankranti
# Best promo type: BOGOF

# %% [markdown]
# ## Highest Revenue Percentage (IR%) product during Sankranti

# %% [markdown]
# Incremental Revenue Percentage (IR%) is calculated as:
#
# $$
# \text{IR\%} = \left(\frac{R_{\text{revenue after promo}} - R_{\text{revenue before promo}}}{R_{\text{revenue before promo}}}\right) \times 100
# $$

# %%
df_merge_1.head(1)
# Out:
#          store_id product_code  base_price(before_promo)  \
# event_id
# 8481be    STCHE-1          P04                       290
#
#           quantity_sold(before_promo) promo_type  base_price(after_promo)  \
# event_id
# 8481be                          327.0    25% OFF                      217
#
#           quantity_sold(after_promo)     city                  product_name  \
# event_id
# 8481be                           287  Chennai  Atliq_Farm_Chakki_Atta (1KG)
#
#                    category campaign_name start_date   end_date
# event_id
# 8481be    Grocery & Staples        Diwali 2023-12-11 2023-11-18

# %%
df_sakranti = df_merge_1.loc[df_merge_1.campaign_name=='Sankranti',['product_code','promo_type','product_name','base_price(before_promo)','quantity_sold(before_promo)','base_price(after_promo)','quantity_sold(after_promo)']]
df_sakranti.head(2)
# Out:
#          product_code    promo_type                          product_name  \
# event_id
# 20618e            P04         BOGOF          Atliq_Farm_Chakki_Atta (1KG)
# 6d153f            P15  500 Cashback  Atliq_Home_Essential_8_Product_Combo
#
#           base_price(before_promo)  quantity_sold(before_promo)  \
# event_id
# 20618e                         370                        379.0
# 6d153f                        3000                        122.0
#
#           base_price(after_promo)  quantity_sold(after_promo)
# event_id
# 20618e                        185                        1622
# 6d153f                       2500                         272

# %%
df_sakranti['revenue(before_promo)']=df_sakranti['base_price(before_promo)'] * df_sakranti['quantity_sold(before_promo)']
df_sakranti['revenue(after_promo)']=df_sakranti['base_price(after_promo)'] * df_sakranti['quantity_sold(after_promo)']

df_sakranti.head(2).T
# Out:
# event_id                                           20618e  \
# product_code                                          P04
# promo_type                                          BOGOF
# product_name                 Atliq_Farm_Chakki_Atta (1KG)
# base_price(before_promo)                              370
# quantity_sold(before_promo)                         379.0
# base_price(after_promo)                               185
# quantity_sold(after_promo)                           1622
# revenue(before_promo)                            140230.0
# revenue(after_promo)                               300070
#
# event_id                                                   6d153f
# product_code                                                  P15
# promo_type                                           500 Cashback
# product_name                 Atliq_Home_Essential_8_Product_Combo
# base_price(before_promo)                                     3000
# quantity_sold(before_promo)                                 122.0
# base_price(after_promo)                                      2500
# quantity_sold(after_promo)                                    272
# revenue(before_promo)                                    366000.0
# revenue(after_promo)                                       680000

# %%
df_ir = df_sakranti.groupby('product_code').agg({
    'product_name': 'first',
    'revenue(before_promo)': 'sum',
    'revenue(after_promo)': 'sum'
})
df_ir
# Out:
#                                            product_name  \
# product_code
# P01                              Atliq_Masoor_Dal (1KG)
# P02                        Atliq_Sonamasuri_Rice (10KG)
# P03                             Atliq_Suflower_Oil (1L)
# P04                        Atliq_Farm_Chakki_Atta (1KG)
# P05                     Atliq_Scrub_Sponge_For_Dishwash
# P06                     Atliq_Fusion_Container_Set_of_3
# P07                                      Atliq_Curtains
# P08                           Atliq_Double_Bedsheet_set
# P09           Atliq_Body_Milk_Nourishing_Lotion (120ML)
# P10             Atliq_Cream_Beauty_Bathing_Soap (125GM)
# P11               Atliq_Doodh_Kesar_Body_Lotion (200ML)
# P12                 Atliq_Lime_Cool_Bathing_Bar (125GM)
# P13                         Atliq_High_Glo_15W_LED_Bulb
# P14                      Atliq_waterproof_Immersion_Rod
# P15                Atliq_Home_Essential_8_Product_Combo
#
#               revenue(before_promo)  revenue(after_promo)
# product_code
# P01                       2175112.0               2011235
# P02                      18622440.0              17262720
# P03                       3240200.0               6118500
# P04                       6813550.0              12779800
# P05                         59675.0                 35875
# P06                        561080.0                342722
# P07                        573600.0               1065450
# P08                       2485910.0               4649330
# P09                        239040.0                146462
# P10                         70400.0                 42328
# P11                        373350.0                258970
# P12                        153450.0                104594
# P13                       1741250.0               3303125
# P14                       4542060.0               8534850
# P15                      16719000.0              31027500

# %%
df_ir['ir_percentage'] = (df_ir['revenue(after_promo)'] - df_ir['revenue(before_promo)'])/df_ir['revenue(before_promo)']*100
df_ir.sort_values('ir_percentage',ascending=False)
# Out:
#                                            product_name  \
# product_code
# P13                         Atliq_High_Glo_15W_LED_Bulb
# P03                             Atliq_Suflower_Oil (1L)
# P14                      Atliq_waterproof_Immersion_Rod
# P04                        Atliq_Farm_Chakki_Atta (1KG)
# P08                           Atliq_Double_Bedsheet_set
# P07                                      Atliq_Curtains
# P15                Atliq_Home_Essential_8_Product_Combo
# P02                        Atliq_Sonamasuri_Rice (10KG)
# P01                              Atliq_Masoor_Dal (1KG)
# P11               Atliq_Doodh_Kesar_Body_Lotion (200ML)
# P12                 Atliq_Lime_Cool_Bathing_Bar (125GM)
# P09           Atliq_Body_Milk_Nourishing_Lotion (120ML)
# P06                     Atliq_Fusion_Container_Set_of_3
# P10             Atliq_Cream_Beauty_Bathing_Soap (125GM)
# P05                     Atliq_Scrub_Sponge_For_Dishwash
#
#               revenue(before_promo)  revenue(after_promo)  ir_percentage
# product_code
# P13                       1741250.0               3303125      89.698492
# P03                       3240200.0               6118500      88.830936
# P14                       4542060.0               8534850      87.907029
# P04                       6813550.0              12779800      87.564485
# P08                       2485910.0               4649330      87.027286
# P07                        573600.0               1065450      85.747908
# P15                      16719000.0              31027500      85.582272
# P02                      18622440.0              17262720      -7.301514
# P01                       2175112.0               2011235      -7.534187
# P11                        373350.0                258970     -30.636132
# P12                        153450.0                104594     -31.838384
# P09                        239040.0                146462     -38.729083
# P06                        561080.0                342722     -38.917445
# P10                         70400.0                 42328     -39.875000
# P05                         59675.0                 35875     -39.882698

# %%
# Get the index (a tuple) of the row with the maximum diff value
best_ir_prod = df_ir['ir_percentage'].idxmax()

# print("Best product:", best_product)
df_ir.loc[df_ir.index == best_ir_prod]
# Out:
#                              product_name  revenue(before_promo)  \
# product_code
# P13           Atliq_High_Glo_15W_LED_Bulb              1741250.0
#
#               revenue(after_promo)  ir_percentage
# product_code
# P13                        3303125      89.698492

# %% [markdown]
# ## Lowest Store Incremental Sold Unit Percentage (ISU%) during Diwali Campaign

# %% [markdown]
# Sold Units Percentage (ISU%) measures the percentage change in the number of units sold due to a promotion, relative to the baseline (units sold before the promotion). In other words, it quantifies how much the promotion increased (or decreased) the number of units sold.
#
# The formula is given by:
# $$
# \text{ISU\%} = \left(\frac{Q_{\text{unit sold after promotion}} - Q_{\text{unit sold before promotion}}}{Q_{\text{unit sold before promotion}}}\right) \times 100
# $$

# %%
df_merge_1.head(1).T
# Out:
# event_id                                           8481be
# store_id                                          STCHE-1
# product_code                                          P04
# base_price(before_promo)                              290
# quantity_sold(before_promo)                         327.0
# promo_type                                        25% OFF
# base_price(after_promo)                               217
# quantity_sold(after_promo)                            287
# city                                              Chennai
# product_name                 Atliq_Farm_Chakki_Atta (1KG)
# category                                Grocery & Staples
# campaign_name                                      Diwali
# start_date                            2023-12-11 00:00:00
# end_date                              2023-11-18 00:00:00

# %%
df_diwali_visa = df_merge_1.loc[(df_merge_1.campaign_name == 'Diwali') & (df_merge_1.city=='Visakhapatnam'),
                        ['store_id','product_code','product_name','quantity_sold(before_promo)','quantity_sold(after_promo)']]
df_diwali_visa.head(1).T
# Out:
# event_id                                          ba86f4
# store_id                                         STVSK-1
# product_code                                         P13
# product_name                 Atliq_High_Glo_15W_LED_Bulb
# quantity_sold(before_promo)                         61.0
# quantity_sold(after_promo)                           204

# %%
df_isu = df_diwali_visa.groupby(['store_id'])[['quantity_sold(before_promo)','quantity_sold(after_promo)']].agg('sum')
df_isu
# Out:
#           quantity_sold(before_promo)  quantity_sold(after_promo)
# store_id
# STVSK-0                        1757.0                        3005
# STVSK-1                        1903.0                        3078
# STVSK-2                        1701.0                        2860
# STVSK-3                        1780.0                        2656
# STVSK-4                        1926.0                        2908

# %%
df_isu['isu_percent'] = (df_isu['quantity_sold(after_promo)'] - df_isu['quantity_sold(before_promo)'])/df_isu['quantity_sold(before_promo)']*100
df_isu = df_isu.sort_values('isu_percent',ascending=True)
df_isu.head()
# Out:
#           quantity_sold(before_promo)  quantity_sold(after_promo)  isu_percent
# store_id
# STVSK-3                        1780.0                        2656    49.213483
# STVSK-4                        1926.0                        2908    50.986501
# STVSK-1                        1903.0                        3078    61.744614
# STVSK-2                        1701.0                        2860    68.136390
# STVSK-0                        1757.0                        3005    71.030165

# %%
# Get the index (a tuple) of the row with the maximum diff value
worst_isu_store = df_isu['isu_percent'].idxmin()
worst_isu_store
# print("Best product:", best_product)
df_isu.loc[df_isu.index == worst_isu_store]
# Out:
#           quantity_sold(before_promo)  quantity_sold(after_promo)  isu_percent
# store_id
# STVSK-3                        1780.0                        2656    49.213483

# %% [markdown]
# ## Negative Promo (based on ISU & IR) during Sankranti

# %%
df_sak = df_sakranti.groupby(['product_code','promo_type'])[['quantity_sold(before_promo)','revenue(before_promo)','quantity_sold(after_promo)','revenue(after_promo)']].agg('sum').reset_index()
df_sak
# Out:
#    product_code    promo_type  quantity_sold(before_promo)  \
# 0           P01       33% OFF                      12646.0
# 1           P02       33% OFF                      21654.0
# 2           P03         BOGOF                      16201.0
# 3           P04         BOGOF                      18415.0
# 4           P05       25% OFF                       1085.0
# 5           P06       25% OFF                       1352.0
# 6           P07         BOGOF                       1912.0
# 7           P08         BOGOF                       2089.0
# 8           P09       25% OFF                       2656.0
# 9           P10       25% OFF                       1408.0
# 10          P11       50% OFF                       1965.0
# 11          P12       50% OFF                       2475.0
# 12          P13         BOGOF                       4975.0
# 13          P14         BOGOF                       4453.0
# 14          P15  500 Cashback                       5573.0
#
#     revenue(before_promo)  quantity_sold(after_promo)  revenue(after_promo)
# 0               2175112.0                       17489               2011235
# 1              18622440.0                       29970              17262720
# 2               3240200.0                       61185               6118500
# 3               6813550.0                       69080              12779800
# 4                 59675.0                         875                 35875
# 5                561080.0                        1102                342722
# 6                573600.0                        7103               1065450
# 7               2485910.0                        7814               4649330
# 8                239040.0                        2186                146462
# 9                 70400.0                        1144                 42328
# 10               373350.0                        2726                258970
# 11               153450.0                        3374                104594
# 12              1741250.0                       18875               3303125
# 13              4542060.0                       16735               8534850
# 14             16719000.0                       12411              31027500

# %%
df_sak['ir_percent'] = (df_sak['revenue(after_promo)']-df_sak['revenue(before_promo)'])/df_sak['revenue(before_promo)']*100
df_sak['isu_percent'] = (df_sak['quantity_sold(after_promo)']-df_sak['quantity_sold(before_promo)'])/df_sak['quantity_sold(before_promo)']*100

df_sak
# Out:
#    product_code    promo_type  quantity_sold(before_promo)  \
# 0           P01       33% OFF                      12646.0
# 1           P02       33% OFF                      21654.0
# 2           P03         BOGOF                      16201.0
# 3           P04         BOGOF                      18415.0
# 4           P05       25% OFF                       1085.0
# 5           P06       25% OFF                       1352.0
# 6           P07         BOGOF                       1912.0
# 7           P08         BOGOF                       2089.0
# 8           P09       25% OFF                       2656.0
# 9           P10       25% OFF                       1408.0
# 10          P11       50% OFF                       1965.0
# 11          P12       50% OFF                       2475.0
# 12          P13         BOGOF                       4975.0
# 13          P14         BOGOF                       4453.0
# 14          P15  500 Cashback                       5573.0
#
#     revenue(before_promo)  quantity_sold(after_promo)  revenue(after_promo)  \
# 0               2175112.0                       17489               2011235
# 1              18622440.0                       29970              17262720
# 2               3240200.0                       61185               6118500
# 3               6813550.0                       69080              12779800
# 4                 59675.0                         875                 35875
# 5                561080.0                        1102                342722
# 6                573600.0                        7103               1065450
# 7               2485910.0                        7814               4649330
# 8                239040.0                        2186                146462
# 9                 70400.0                        1144                 42328
# 10               373350.0                        2726                258970
# 11               153450.0                        3374                104594
# 12              1741250.0                       18875               3303125
# 13              4542060.0                       16735               8534850
# 14             16719000.0                       12411              31027500
#
#     ir_percent  isu_percent
# 0    -7.534187    38.296695
# 1    -7.301514    38.403990
# 2    88.830936   277.661873
# 3    87.564485   275.128971
# 4   -39.882698   -19.354839
# 5   -38.917445   -18.491124
# 6    85.747908   271.495816
# 7    87.027286   274.054572
# 8   -38.729083   -17.695783
# 9   -39.875000   -18.750000
# 10  -30.636132    38.727735
# 11  -31.838384    36.323232
# 12   89.698492   279.396985
# 13   87.907029   275.814058
# 14   85.582272   122.698726

# %%
df_sak.loc[(df_sak['ir_percent'] < 0) & (df_sak['isu_percent'] < 0)]
# Out:
#   product_code promo_type  quantity_sold(before_promo)  revenue(before_promo)  \
# 4          P05    25% OFF                       1085.0                59675.0
# 5          P06    25% OFF                       1352.0               561080.0
# 8          P09    25% OFF                       2656.0               239040.0
# 9          P10    25% OFF                       1408.0                70400.0
#
#    quantity_sold(after_promo)  revenue(after_promo)  ir_percent  isu_percent
# 4                         875                 35875  -39.882698   -19.354839
# 5                        1102                342722  -38.917445   -18.491124
# 8                        2186                146462  -38.729083   -17.695783
# 9                        1144                 42328  -39.875000   -18.750000

# %%
df_merge_1.head(1).T
# Out:
# event_id                                           8481be
# store_id                                          STCHE-1
# product_code                                          P04
# base_price(before_promo)                              290
# quantity_sold(before_promo)                         327.0
# promo_type                                        25% OFF
# base_price(after_promo)                               217
# quantity_sold(after_promo)                            287
# city                                              Chennai
# product_name                 Atliq_Farm_Chakki_Atta (1KG)
# category                                Grocery & Staples
# campaign_name                                      Diwali
# start_date                            2023-12-11 00:00:00
# end_date                              2023-11-18 00:00:00

# %%
df_merge_1.groupby('category')['base_price(before_promo)'].agg('min')
# Out:
# category
# Combo1               3000
# Grocery & Staples     156
# Home Appliances       350
# Home Care              55
# Personal Care          50
# Name: base_price(before_promo), dtype: int64
